# %% [markdown]
# # Employees Attrition
# ## Introduction
# the employees attrtion data show the number of employees that are active and those that terminated.
#
# The intent is to see if individual terminations can be predicted from the data provided.
#
# The thing to be predicted is status of active or terminated
#
# The data containsemployee id employee record date ( year of data) birth date hire date termination date age length of service city department job title store number gender termination reason termination type status year status business unit

# %%
#importing necessary libraries 
import pandas as pd
import numpy as np

print('numpy version:', np.__version__)
print('matplotlib version:', pd.__version__)
from sklearn import svm
import matplotlib.pyplot as plt
import seaborn as sns;sns.set(font_scale=1.2)
from sklearn.model_selection import cross_val_score

# Allows charts to appear in the notebook
# %matplotlib inline
#Loading the csv file
df_Emp = pd.read_csv("EmployeesAttrion.csv", encoding="ISO-8859-1",  sep=",",low_memory=False)
# Out:
# numpy version: 1.15.1
# matplotlib version: 0.23.4

# %% [markdown]
# # Overview of Data

# %%
df_Emp
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5            1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6            1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7            1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8            1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9            1318  12/31/2015 0:00      1/3/1954        8/28/1989
# 10           1319  12/31/2006 0:00      1/3/1957        8/28/1989
# 11           1319  12/31/2007 0:00      1/3/1957        8/28/1989
# 12           1319  12/31/2008 0:00      1/3/1957        8/28/1989
# ...

# %%
#shape function prints the number of rows and columns 
print('Employees dataset shape: {}'.format(df_Emp.shape))
# df_Emp
# Out:
# Employees dataset shape: (49653, 18)

# %%
#shows the datatypes in our dataset
df_Emp.dtypes
# Out:
# EmployeeID              int64
# recorddate_key         object
# birthdate_key          object
# orighiredate_key       object
# terminationdate_key    object
# age                     int64
# length_of_service       int64
# city_name              object
# department_name        object
# job_title              object
# store_name              int64
# gender_short           object
# gender_full            object
# termreason_desc        object
# termtype_desc          object
# STATUS_YEAR             int64
# STATUS                 object
# BUSINESS_UNIT          object
# dtype: object

# %%
#gives the general overview of rangeIndex and the number of datatypes e.g int(6) that means how many numeric columns we have in our data
#and value types (null or not null)
df_Emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49653 entries, 0 to 49652
# Data columns (total 18 columns):
# EmployeeID             49653 non-null int64
# recorddate_key         49653 non-null object
# birthdate_key          49653 non-null object
# orighiredate_key       49653 non-null object
# terminationdate_key    49653 non-null object
# age                    49653 non-null int64
# length_of_service      49653 non-null int64
# city_name              49653 non-null object
# department_name        49653 non-null object
# job_title              49653 non-null object
# store_name             49653 non-null int64
# gender_short           49653 non-null object
# gender_full            49653 non-null object
# termreason_desc        49653 non-null object
# termtype_desc          49653 non-null object
# STATUS_YEAR            49653 non-null int64
# STATUS                 49653 non-null object
# BUSINESS_UNIT          49653 non-null object
# dtypes: int64(5), object(13)
# ...

# %%
#describes count mean min max of numeric values in our data
df_Emp.describe()
# Out:
#          EmployeeID           age  length_of_service    store_name  \
# count  49653.000000  49653.000000       49653.000000  49653.000000
# mean    4859.495740     42.077035          10.434596     27.297605
# std     1826.571142     12.427257           6.325286     13.514134
# min     1318.000000     19.000000           0.000000      1.000000
# 25%     3360.000000     31.000000           5.000000     16.000000
# 50%     5031.000000     42.000000          10.000000     28.000000
# 75%     6335.000000     53.000000          15.000000     42.000000
# max     8336.000000     65.000000          26.000000     46.000000
#
#         STATUS_YEAR
# count  49653.000000
# mean    2010.612612
# std        2.845577
# min     2006.000000
# 25%     2008.000000
# 50%     2011.000000
# 75%     2013.000000
# max     2015.000000

# %% [markdown]
# # Exploratory analysis

# %%
#male and female employees
plt.figure(figsize=[7,7])
plt.style.use("ggplot")
df_Emp['gender_full'].value_counts().plot(kind='bar')

# %% [markdown]
# The figure above shows the total number of male and female employees in data

# %%
count_emp_male = df_Emp['gender_full'].str.count('Male')
count_emp_female = df_Emp['gender_full'].str.count('Female')

pie_values = [count_emp_male.sum(), count_emp_female.sum()]
pie_labels = 'Male', 'Female'

plt.pie(pie_values, labels=pie_labels, autopct='%1.1f%%', shadow=True, startangle=90, rotatelabels=True, colors = {'red', 'green'})

plt.axis('equal')

plt.title('Percentage of male/female employees')
plt.show()

# %% [markdown]
# This figure shows the same amount of male and female employees in piechart

# %%
# #Replacing the old objects with the new optimized converted objects
# optimized_df_Emp[converted_df_Emp_obj.columns] = converted_df_Emp_obj

# #Printing the memory usage of the dataframe
# print(mem_usage(optimized_df_Emp))

# %%
df_Emp['age'].hist()
plt.title('Age of Employees')
plt.xlabel('Age')
plt.ylabel('Amount of Employees')
plt.show()

df_Emp[(df_Emp['gender_full'] == 'Male')]['age'].hist(color = 'navy')
plt.title('Age of male Employees')
plt.xlabel('age')
plt.ylabel('Amount of Employees')
plt.show()

df_Emp[(df_Emp['gender_full'] == 'Female')]['age'].hist(color = 'hotpink')
plt.title('Age of female Employees')
plt.xlabel('Age')
plt.ylabel('Amount of Employees')
plt.show()

# %% [markdown]
# The first figure shows the age of both men and women
#
#  second figure shows the age of male employees
#
#  third figure shows the age of female employees

# %%
#find the counts for each department
count_per_dept=df_Emp['department_name'].value_counts()
count_per_dept
# Out:
# Meats                     10269
# Dairy                      8599
# Produce                    8515
# Bakery                     8381
# Customer Service           7122
# Processed Foods            5911
# Store Management            271
# Executive                   100
# Recruitment                  72
# HR Technology                64
# Accounting                   59
# Employee Records             44
# Accounts Receiveable         39
# Labor Relations              34
# Accounts Payable             34
# Training                     30
# Investment                   24
# Compensation                 24
# Audit                        24
# Information Technology       20
# Legal                        17
# Name: department_name, dtype: int64

# %% [markdown]
# #This counts the number of employees as per each departmen

# %%
fig=plt.figure(figsize=[7,7])
ax=fig.gca()
count_per_dept.plot.bar(ax=ax)
ax.set_title("Departments")
ax.set_ylabel("Number of workers")
ax.set_xlabel("Departments")
# Out:
# Text(0.5,0,'Departments')

# %% [markdown]
# the above figure count the number of employees as per each department

# %%
# df_Emp[(df_Emp['gender_full'] == 'Male')]['STATUS'].hist(color = 'navy')
# plt.title(' Status of male Employees')
# plt.xlabel('Status')
# plt.ylabel('Amount of Employees')
# plt.show()
# df_Emp['STATUS'].hist()
# plt.title('Age of Employees')
# plt.xlabel('Age')
# plt.ylabel('Amount of Employees')
# plt.show()
plt.figure(figsize=[7,7])
plt.style.use("ggplot")
df_Emp['STATUS'].value_counts().plot(kind='bar')

# %% [markdown]
# The figure above shows number of active and deactive employees

# %%
#Look at missing values
df_Emp.isnull().sum()
# Out:
# EmployeeID             0
# recorddate_key         0
# birthdate_key          0
# orighiredate_key       0
# terminationdate_key    0
# age                    0
# length_of_service      0
# city_name              0
# department_name        0
# job_title              0
# store_name             0
# gender_short           0
# gender_full            0
# termreason_desc        0
# termtype_desc          0
# STATUS_YEAR            0
# STATUS                 0
# BUSINESS_UNIT          0
# dtype: int64

# %% [markdown]
# no missing values are found in the data

# %%
# store our transformation in a new column, so the original Status isn't changed.
df_Emp['status'] = df_Emp['STATUS'].map( {'TERMINATED': 1, 'ACTIVE': 0} ).astype(int)
df_Emp.head(3)
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT  status
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE       0
# ...

# %%
#find the counts for each department
count_per_dept=df_Emp['termreason_desc'].value_counts()
count_per_dept
fig=plt.figure(figsize=[5,5])
ax=fig.gca()
count_per_dept.plot.bar(ax=ax)
ax.set_title("Reason of Termination")
ax.set_ylabel("Number of workers")
ax.set_xlabel("Reason")
# Out:
# Text(0.5,0,'Reason')

# %% [markdown]
# This figure shows the reson of termination and shows the number of employees who terminated the job as per each reason

# %%
#find the termination type for each department
count_per_dept=df_Emp['termtype_desc'].value_counts()
count_per_dept
fig=plt.figure(figsize=[7,7])
ax=fig.gca()
count_per_dept.plot.bar(ax=ax)
ax.set_title("Type")
ax.set_ylabel("Number of workers")
ax.set_xlabel("TypeEmp")
# Out:
# Text(0.5,0,'TypeEmp')

# %%
#find the counts for each city
count_per_dept=df_Emp['city_name'].value_counts()
count_per_dept
fig=plt.figure(figsize=[20,20])
ax=fig.gca()
count_per_dept.plot.bar(ax=ax)
ax.set_title("Locations")
ax.set_ylabel("Number of workers")
ax.set_xlabel("Cities")
# Out:
# Text(0.5,0,'Cities')

# %% [markdown]
# this figure shows the number of employees from different cities in canada

# %%
df_Emp['GENDER'] = df_Emp['gender_full'].map( {'Male': 0, 'Female': 1} ).astype(int)
df_Emp.head(3)
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# 1       CEO          35            M        Male  Not Applicable
# 2       CEO          35            M        Male  Not Applicable
#
#     termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT  status  GENDER
# 0  Not Applicable         2006  ACTIVE    HEADOFFICE       0       0
# ...

# %%
df_terminated_male=df_Emp[(df_Emp.GENDER == 0) & (df_Emp.STATUS == "TERMINATED") ]
df_terminated_male
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 48168        1338   2/1/2009 0:00     2/16/1949        9/20/1989
# 48170        1340   2/1/2009 0:00     2/19/1949        9/22/1989
# 48171        1341   2/1/2009 0:00     2/21/1949        9/23/1989
# 48175        1347   3/1/2009 0:00      3/4/1949        9/29/1989
# 48176        1351   3/1/2009 0:00      3/9/1949        10/2/1989
# 48178        1353   3/1/2009 0:00     3/13/1949        10/4/1989
# 48179        1355   3/1/2009 0:00     3/15/1949        10/5/1989
# 48180        1357   3/1/2009 0:00     3/14/1949        10/5/1989
# 48181        1358   3/1/2009 0:00     3/14/1949        10/5/1989
# 48185        1363   3/1/2009 0:00     3/20/1949        10/8/1989
# 48187        1366   3/1/2009 0:00     3/26/1949       10/11/1989
# 48188        1367   3/1/2009 0:00     3/27/1949       10/11/1989
# 48190        1372   4/1/2009 0:00      4/5/1949       10/16/1989
# ...

# %%
df_terminated_Female=df_Emp[(df_Emp.GENDER == 1) & (df_Emp.STATUS == "TERMINATED") ]
df_terminated_Female
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 48169        1339   2/1/2014 0:00     2/19/1949        9/22/1989
# 48172        1343   2/1/2014 0:00     2/24/1949        9/25/1989
# 48173        1344   2/1/2014 0:00     2/25/1949        9/25/1989
# 48174        1346   3/1/2014 0:00      3/4/1949        9/29/1989
# 48177        1352   3/1/2014 0:00     3/11/1949        10/3/1989
# 48182        1359   3/1/2014 0:00     3/16/1949        10/6/1989
# 48183        1360   3/1/2014 0:00     3/17/1949        10/6/1989
# 48184        1362   3/1/2014 0:00     3/18/1949        10/7/1989
# 48186        1365   9/1/2012 0:00     3/24/1949       10/10/1989
# 48189        1370   4/1/2014 0:00      4/1/1949       10/14/1989
# 48191        1373   4/1/2014 0:00      4/4/1949       10/16/1989
# 48194        1377   4/1/2014 0:00     4/15/1949       10/22/1989
# 48195        1380   4/1/2014 0:00     4/15/1949       10/22/1989
# ...

# %%
#More females terminated the job

# %%
plt.figure(figsize=[7,7])
plt.style.use("ggplot")
df_terminated_male['STATUS'].value_counts().plot(kind='bar')

plt.figure(figsize=[7,7])
plt.legend("female")
plt.style.use("ggplot")
df_terminated_Female['STATUS'].value_counts().plot(kind='bar')

# %% [markdown]
#  First figure shows the number of males who terminated the job
#
# second figure shows the number of females who terminated the job
#
# more females terminated the job

# %%
df_stores_unit=df_Emp[(df_Emp.GENDER == 1) & (df_Emp.BUSINESS_UNIT == "STORES") ]

# %%
count_emp_male = df_Emp['BUSINESS_UNIT'].str.count('STORES')
count_emp_female = df_Emp['BUSINESS_UNIT'].str.count('HEADOFFICE')

pie_values = [count_emp_male.sum(), count_emp_female.sum()]
pie_labels = 'STORES', 'HEADOFFICE'

plt.pie(pie_values, labels=pie_labels, autopct='%1.1f%%', shadow=True, startangle=90, rotatelabels=True, colors = {'red', 'green'})

plt.axis('equal')

plt.title('Percentage of STORES/HEADOFFICES employees')
plt.show()

# %% [markdown]
# #percentage of employees who work in stores and headOffices
# #98% employees work in stores

# %%
df_term=df_Emp[(df_Emp.age>20) & (df_Emp.STATUS == "TERMINATED") ]

# %%
#calculate the terminated status of the people by age
plt.figure(figsize=[20,10])
plt.style.use("ggplot")
plt.xlabel("Age")
plt.ylabel("terminations")
df_term['age'].value_counts().plot(kind='bar')

# fig=plt.figure(figsize=[20,20])
# ax=fig.gca()
# df_term.plot.bar(ax=ax)
# ax.set_ylabel("Number of workers")
# ax.set_xlabel("ages")

# %% [markdown]
# Show the number of termination according to employees age

# %%
# df_jobs=df_Emp[(df_Emp.age>20) & (df_Emp.job_title == "TERMINATED") ]
df_jobs=df_Emp.loc[:,['age','STATUS','job_title']]
df_jobs
# Out:
#        age      STATUS      job_title
# 0       52      ACTIVE            CEO
# 1       53      ACTIVE            CEO
# 2       54      ACTIVE            CEO
# 3       55      ACTIVE            CEO
# 4       56      ACTIVE            CEO
# 5       57      ACTIVE            CEO
# 6       58      ACTIVE            CEO
# 7       59      ACTIVE            CEO
# 8       60      ACTIVE            CEO
# 9       61      ACTIVE            CEO
# 10      49      ACTIVE      VP Stores
# 11      50      ACTIVE      VP Stores
# 12      51      ACTIVE      VP Stores
# 13      52      ACTIVE      VP Stores
# 14      53      ACTIVE      VP Stores
# 15      54      ACTIVE      VP Stores
# 16      55      ACTIVE      VP Stores
# 17      56      ACTIVE      VP Stores
# 18      57      ACTIVE      VP Stores
# 19      58      ACTIVE      VP Stores
# 20      51      ACTIVE  Legal Counsel
# 21      52      ACTIVE  Legal Counsel
# 22      53      ACTIVE  Legal Counsel
# 23      54      ACTIVE  Legal Counsel
# ...

# %%
# df_cashiers = df_Emp[df_Emp['job_title'] == 'Cashier']
# # print(df_cashiers)
# plt.figure(figsize=[20,20])

# plt.subplot(1,2,1)
# plt.scatter(df_cashiers.STATUS,df_cashiers.age )

# %%
# look at number of terminations per year.
# Count terminations per year
df_term_per_year=df_Emp[(df_Emp.age>=20) & (df_Emp.STATUS == "TERMINATED")& (df_Emp.STATUS_YEAR) ]
df_term_per_year
count_per_yr=df_term['STATUS_YEAR'].value_counts()
fig=plt.figure(figsize=[15,15])
ax=fig.gca()
count_per_yr.plot.bar(ax=ax)
ax.set_title("Type")
ax.set_ylabel("Number of workers")
ax.set_xlabel("Termination per year")
# Out:
# Text(0.5,0,'Termination per year')

# %% [markdown]
# #This figures shows the number of terminations per year. Terminations are increasing over time

# %%
#check the people who are over 20 years of age and terminated their job 
df_term=df_Emp[(df_Emp.age>=20) & (df_Emp.STATUS == "TERMINATED")& (df_Emp.termreason_desc)& (df_Emp.job_title) ]
df_term
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 48168        1338   2/1/2009 0:00     2/16/1949        9/20/1989
# 48169        1339   2/1/2014 0:00     2/19/1949        9/22/1989
# 48170        1340   2/1/2009 0:00     2/19/1949        9/22/1989
# 48171        1341   2/1/2009 0:00     2/21/1949        9/23/1989
# 48172        1343   2/1/2014 0:00     2/24/1949        9/25/1989
# 48173        1344   2/1/2014 0:00     2/25/1949        9/25/1989
# 48174        1346   3/1/2014 0:00      3/4/1949        9/29/1989
# 48175        1347   3/1/2009 0:00      3/4/1949        9/29/1989
# 48176        1351   3/1/2009 0:00      3/9/1949        10/2/1989
# 48177        1352   3/1/2014 0:00     3/11/1949        10/3/1989
# 48178        1353   3/1/2009 0:00     3/13/1949        10/4/1989
# 48179        1355   3/1/2009 0:00     3/15/1949        10/5/1989
# 48180        1357   3/1/2009 0:00     3/14/1949        10/5/1989
# ...

# %% [markdown]
# #in total 1474 have terminated the job
# #by age 60+ have been retired
# #by job_title young people are resigning cashier job in the department of customer service

# %%
count_per_dept=df_term['job_title'].value_counts().sum()
count_per_dept
# Out:
# 1480

# %%
#find the counts for each terminated job
count_per_dept=df_term['job_title'].value_counts()
count_per_dept
fig=plt.figure(figsize=[10,10])
ax=fig.gca()
count_per_dept.plot.bar(ax=ax)
ax.set_title("Overall Terminations")
ax.set_ylabel("Number of workers")
ax.set_xlabel("TypeEmp")
# Out:
# Text(0.5,0,'TypeEmp')

# %% [markdown]
# The figure above show the number of termination as per each job titile overall

# %%
#Resignationss
df_resg=df_Emp[(df_Emp.age>=20) & (df_Emp.STATUS == "TERMINATED")& (df_Emp.termreason_desc=="Resignaton")& (df_Emp.job_title) ]
df_resg
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 48186        1365   9/1/2012 0:00     3/24/1949       10/10/1989
# 48265        1484   7/1/2007 0:00    11/22/1949        2/15/1990
# 48354        1624   3/1/2011 0:00      8/3/1950        6/29/1990
# 48372        1653  10/1/2011 0:00    10/12/1950         8/5/1990
# 48395        1714  10/1/2007 0:00     1/30/1951        10/2/1990
# 48409        1823   4/1/2007 0:00     10/6/1951        2/11/1991
# 48411        1885   1/1/2012 0:00      2/7/1952        4/17/1991
# 48415        1951   9/1/2006 0:00      7/5/1952         7/5/1991
# 48416        1998   3/1/2009 0:00     9/21/1952        8/15/1991
# 48420        2127   9/1/2011 0:00     6/25/1953         1/9/1992
# 48421        2164   4/1/2010 0:00     9/11/1953        2/19/1992
# 48422        2266   9/1/2006 0:00      4/5/1954         6/6/1992
# 48425        2310   3/1/2008 0:00     7/18/1954        7/31/1992
# ...

# %%
count_per_job=df_resg['job_title'].value_counts()
fig=plt.figure(figsize=[7,7])
ax=fig.gca()
count_per_job.plot.bar(ax=ax)
ax.set_title("Resignation")
ax.set_ylabel("Number of workers")
ax.set_xlabel("TypeEmp")
# Out:
# Text(0.5,0,'TypeEmp')

# %% [markdown]
# The above figure shows the number of terminations as per each job_title whose termination reason was resignation

# %%
#Checking correlation 
plt.figure(figsize=(10,8))
sns.heatmap(df_Emp.corr(),linewidths=.1,cmap="YlGnBu", annot=True)
plt.yticks(rotation=0);

# %% [markdown]
# ### Checking different job titles

# %%
df_Emp.job_title.value_counts()
# Out:
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# Baker                              8096
# Cashier                            6816
# Shelf Stocker                      5622
# Customer Service Manager            306
# Processed Foods Manager             289
# Bakery Manager                      285
# Meats Manager                       285
# Produce Manager                     278
# Store Manager                       271
# Recruiter                            62
# HRIS Analyst                         55
# Accounting Clerk                     50
# Benefits Admin                       35
# Accounts Receiveable Clerk           30
# Labor Relations Analyst              30
# Trainer                              26
# Accounts Payable Clerk               25
# Auditor                              20
# Investment Analyst                   20
# Compensation Analyst                 20
# ...

# %%
# The 47 jobs can be separated
employee = ['Meat Cutter', 'Dairy Person', 'Produce Clerk', 'Baker', 'Cashier',
            'Shelf Stocker', 'Recruiter', 'HRIS Analyst', 'Accounting Clerk',
            'Benefits Admin', 'Labor Relations Analyst', 'Accounts Receiveable Clerk',
            'Accounts Payable Clerk', 'Auditor', 'Compensation Analyst',
            'Investment Analyst', 'Systems Analyst', 'Corporate Lawyer', 'Legal Counsel']

manager = ['Customer Service Manager', 'Processed Foods Manager', 'Meats Manager',
           'Bakery Manager', 'Produce Manager', 'Store Manager', 'Trainer', 'Dairy Manager']

executive = ['Exec Assistant, Finance', 'Exec Assistant, Legal Counsel',
             'CHief Information Officer', 'CEO', 'Exec Assistant, Human Resources',
             'Exec Assistant, VP Stores']

board = ['VP Stores', 'Director, Recruitment', 'VP Human Resources', 'VP Finance',
         'Director, Accounts Receivable', 'Director, Accounting',
         'Director, Employee Records', 'Director, Accounts Payable',
         'Director, HR Technology', 'Director, Investments',
         'Director, Labor Relations', 'Director, Audit', 'Director, Training',
         'Director, Compensation']
# Check all jobs were entered into the categories
total = len(employee) + len(manager) + len(executive) + len(board)
print('Total jobs categorised:', total, 'out of 47')
# Out:
# Total jobs categorised: 47 out of 47

# %%
df_Emp['copy_job_title']=df_Emp.job_title
df_Emp.copy_job_title = df_Emp.copy_job_title.replace(employee, 0)
df_Emp.copy_job_title = df_Emp.copy_job_title.replace(manager, 1)
df_Emp.copy_job_title = df_Emp.copy_job_title.replace(executive, 2)
df_Emp.copy_job_title = df_Emp.copy_job_title.replace(board, 3)

# Check that the replacement went to plan
df_Emp.copy_job_title.value_counts()
# Out:
# 0    47739
# 1     1749
# 3      105
# 2       60
# Name: copy_job_title, dtype: int64

# %%
#Checking how many are in company and how many of them are out of company 
#Using the predictor features
out_of_company = df_Emp[df_Emp.status == 1]
in_company = df_Emp[df_Emp.status == 0]

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharex=True, sharey=True)

ax1.scatter(out_of_company.age, out_of_company.length_of_service, color='r')
ax1.set_xlabel('Age')
ax1.set_ylabel('Length of service')
ax1.set_title('Out of company')

ax2.scatter(in_company.age, in_company.length_of_service, color='b')
ax2.set_xlabel('Age')
ax2.set_title('In company')
# Out:
# Text(0.5,1,'In company')

# %% [markdown]
# People may leave the company after working for any length of time from 0 to 25 years and any age from 20 to 60. Take a closer look at the distribution of ages and service times for terminations.

# %%
g = sns.jointplot(out_of_company.age, out_of_company.length_of_service, color='g')
# Out:
# C:\Users\Ali\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# There appear to be 3 peaks in the age when people stop working. There are 4 major peaks in the length of service before people stop working.

# %%
# df_Emp['copy_year'] = df_Emp[(df_Emp.STATUS_YEAR==2013)]
df_copy=df_Emp[df_Emp['STATUS_YEAR'] < 2014]
df_copy
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5            1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6            1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7            1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 10           1319  12/31/2006 0:00      1/3/1957        8/28/1989
# 11           1319  12/31/2007 0:00      1/3/1957        8/28/1989
# 12           1319  12/31/2008 0:00      1/3/1957        8/28/1989
# 13           1319  12/31/2009 0:00      1/3/1957        8/28/1989
# 14           1319  12/31/2010 0:00      1/3/1957        8/28/1989
# ...

# %%
 order = df_Emp.groupby('STATUS_YEAR')['status'].sum().reset_index()
# order = df_orders['Count'].count()
#  order

# %%
from datetime import datetime
# df_orders['Order date']
order = order.set_index('STATUS_YEAR')
order.index
# Out:
# Int64Index([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015], dtype='int64', name='STATUS_YEAR')

# %%
# y = pd.to_datetime(df_Emp['length_of_service'], errors='coerce')
# y = order['length_of_service'].resample('MS').mean()

# %%
y.plot(figsize=(10, 6))
plt.title('Observed ')
plt.xlabel('Years')
plt.ylabel('Number ')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-02534c1bf525> in <module>()
# ----> 1 y.plot(figsize=(10, 6))
#       2 plt.title('Observed ')
#       3 plt.xlabel('Years')
#       4 plt.ylabel('Number ')
#       5 plt.show()
#
# NameError: name 'y' is not defined

# %% [markdown]
# # Decsion tree

# %%
# df_Emp['GENDER'] = df_Emp['gender_full'].map( {'Male': 1, 'Female': 0} ).astype(int)

# %%
Emp_X = df_copy[['age','GENDER','length_of_service','copy_job_title']]
#titanic_X = df_titanic[['AgeFill','Gender']]
Emp_y = df_copy['status']

# %%
Emp_X.head()

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
 #splits the data into training and test 
X_train, X_test, y_train, y_test = train_test_split(Emp_X,Emp_y, test_size=0.2)  
#prints the shape of training and test data and adding cross validation
kf = KFold(n_splits=10,random_state=0)
kf.get_n_splits(X_train,y_train) 
print(kf)
print('Train shape:', X_train.shape, y_train.shape)
print('Test shape:', X_test.shape, y_test.shape)

# %%
from sklearn import tree
from sklearn import metrics


clf=tree.DecisionTreeClassifier(criterion = "entropy", min_samples_split = 5, max_depth =10 ,random_state=0)
clf.fit(X_train,y_train)

# %%
predictionsDtree = clf.predict(X_test)
metrics.accuracy_score(y_test,predictionsDtree)

# %%
import seaborn as sn
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import confusion_matrix,classification_report

CM = confusion_matrix(y_test,predictionsDtree)


print(CM)
print(classification_report(y_test,predictionsDtree))

# %%
plt.figure(figsize = (5,5))

sn.heatmap(CM, annot=True)

# %%
import graphviz
dot_data = tree.export_graphviz(clf, out_file =None, feature_names = ['age','GENDER','length_of_service','copy_job_title'],
                                           class_names = ['Terminated', 'Activated'])
graph = graphviz.Source(dot_data)
graph

# %%
## Adding cross validation

# %%
from sklearn.model_selection import cross_val_score
ac=cross_val_score(estimator=clf,X=X_train,y=y_train,cv=10)
ac

# %%
ac.mean()

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(classification_report(y_test,predictionsDtree))

# %%
df_copy.head()

# %% [markdown]
# # SVM

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
param_grid = [
  
  {'C': [1, 10, 100, 1000], 'gamma': [1,0.001, 0.0001], 'kernel': ['rbf']},
 ]

# %%
gridSVM = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)

# %%
gridSVM.fit(X_train,y_train)

# %%
gridSVM.best_params_

# %%
#adding svm and fitting kernel svm to the training set

classifier=svm.SVC(C=1,gamma=1,kernel='rbf',random_state=0)
#classifier.fit(x,y.ravel())
classifier.fit(X_train,y_train.ravel())

# %%
#predicting the test_Set results
predsvm=classifier.predict(X_test)
print(predsvm)

# %%
metrics.accuracy_score(y_test,predsvm)

# %%
from sklearn.metrics import f1_score
F1=f1_score(y_test,predsvm)
F1

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
con_mat=confusion_matrix(y_test,predsvm)
print(con_mat)
# print(classification_report(y_test,predsvm))

# %%
plt.figure(figsize = (5,5))
sn.heatmap(con_mat, annot=True)

# %%
#Applying k_fold cross validation
from sklearn.model_selection import cross_val_score
K_FOLD=cross_val_score(estimator=classifier,X=X_train,y=y_train.ravel(),cv=10)
K_FOLD

# %%
K_FOLD.mean()

# %%
print(classification_report(y_test,predsvm))

# %% [markdown]
# # knn

# %%
from sklearn.neighbors import KNeighborsClassifier

error_rate = []
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test)) # avrage error rate were not equal to the actual
# test value

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')

# %%
knn = KNeighborsClassifier(n_neighbors=10)

# %%
knn.fit(X_train,y_train)

# %%
Knnpred = knn.predict(X_test)
print(Knnpred)

# %%
print(confusion_matrix(y_test,Knnpred))
print(classification_report(y_test,Knnpred))
print('K value 10 has yielded the best accurace rate')

# %%
accuracies = cross_val_score(estimator=knn,X=X_train,y=y_train,cv=10 )
print(accuracies)
print(accuracies.mean())

# %% [markdown]
# # End
